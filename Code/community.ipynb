# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import scipy as sp

# Data reading
import pandas as pd
import csv
import pickle

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# networkx

import networkx as nx
from networkx.algorithms import community
from networkx.algorithms.community import greedy_modularity_communities
from networkx.algorithms.community import k_clique_communities

from community import community_louvain

import scipy.sparse.linalg

# %%
# Read networks from file
#G_CDC28=nx.read_weighted_edgelist("./../Data/4932_protein_links_v11_0.txt",comments="#",nodetype=str)
G_CDC28=nx.read_weighted_edgelist("4932.protein.links.v11.0.txt",comments="#",nodetype=str)

print('number of nodes of G:',nx.number_of_nodes(G_CDC28))
print('number of edges of G:',nx.number_of_edges(G_CDC28))
# Out:
# number of nodes of G: 6574
# number of edges of G: 922983

# %%
node_target = '4932.YBR160W' #CDC28
print('The target node has %i links'%G_CDC28.degree(node_target))
# Out:
# The target node has 1401 links

# %%
# Choose the network to be analyzed below
G0=G_CDC28
# delete those edges with a combined score of <= thershold_score (small confidence)
threshold_score = 700
#threshold_score = 0
for edge in G0.edges: 
    G0.get_edge_data(edge[0],edge[1])
    weight = list(G0.get_edge_data(edge[0],edge[1]).values())
    #print('qwe',weight[0])
    if(weight[0] <= threshold_score):
        G0.remove_edge(edge[0],edge[1])
# restrict to largest connected component
largest_cc = max(nx.connected_components(G0),key=len)
G0=G0.subgraph(largest_cc)

# %%
partLouvain = community_louvain.best_partition(G0,resolution=0.5,random_state=1)
number_of_communities = max(list(partLouvain.values()))+1
print('# of partitions for Louvain modularity =',number_of_communities)
# Out:
# # of partitions for Louvain modularity = 29

# %%
node_target = '4932.YBR160W' # CDC28
print('The target protein CDC28 belongs to community #',partLouvain[node_target])
# Out:
# The target protein CDC28 belongs to community # 3

# %%
# define the communities as separate graphs

#subgraph dict with community number as key and subgraph as value
G_cluster = {}

#node dict with community number as key and node as value
nodes = {}
for i in range(number_of_communities):
    nodes[i] = []

for name, community in partLouvain.items():
    nodes[community].append(name)
    
for key in nodes.keys():
    G_cluster[key] = G0.subgraph(nodes[key])

# %%
top10_final = {}
for i in range(number_of_communities):
    top10_final[i] = []
    G = G_cluster[i]
    measuresNames=["Degree","Eigenvector","Page Rank"]
    if len(G.nodes)>2:
        listMeasures = [dict(nx.degree(G)),nx.eigenvector_centrality_numpy(G),nx.pagerank(G)]
   
    if len(G.nodes)<=2:
        listMeasures = [dict(nx.degree(G)),nx.eigenvector_centrality(G),nx.pagerank(G)]
   
    for idx,dictMeasure in enumerate(listMeasures):
        top10 = [[dictMeasure[k],k] for k in dictMeasure.keys()] # Choose the 10 largest values
        top10.sort(reverse=True)
        top10_final[i].append(top10)
        print("\n Centrality Measure in Cluster:",str(i),measuresNames[idx])
        for idx,pair in enumerate(top10[:10]):
            print(str(idx+1),": \t is node ",pair[1],' with value: %.4f \t' %(pair[0]))
# Out:
# 2.YJL034W  with value: 0.0162
# 2 : 	 is node  4932.YPL240C  with value: 0.0151
# 3 : 	 is node  4932.YMR186W  with value: 0.0121
# 4 : 	 is node  4932.YOR027W  with value: 0.0117
# 5 : 	 is node  4932.YPL106C  with value: 0.0105
# 6 : 	 is node  4932.YCL043C  with value: 0.0105
# 7 : 	 is node  4932.YNL064C  with value: 0.0100
# 8 : 	 is node  4932.YEL029C  with value: 0.0095
# 9 : 	 is node  4932.YKL073W  with value: 0.0094
# 10 : 	 is node  4932.YJR156C  with value: 0.0091
#
#  Centrality Measure in Cluster: 17 Degree
# 1 : 	 is node  4932.YEL061C  with value: 69.0000
# 2 : 	 is node  4932.YCL029C  with value: 68.0000
# 3 : 	 is node  4932.YPL269W  with value: 67.0000
# 4 : 	 is node  4932.YLR045C  with value: 65.0000
# 5 : 	 is node  4932.YOR195W  with value: 63.0000
# 6 : 	 is node  4932.YDL028C  with value: 62.0000
# 7 : 	 is node  4932.YOL069W  with value: 60.0000
# 8 : 	 is node  4932.YJL030W  with value: 60.0000
# 9 : 	 is node  4932.YPL018W  with value: 57.0000
# 10 : 	 is node  4932.YMR117C  with value: 57.0000
#
#  Centrality Measure in Cluster: 17 Eigenvector
# 1 : 	 is node  4932.YEL061C  with value: 0.1420
# 2 : 	 is node  4932.YLR045C  with value: 0.1406
# 3 : 	 is node  4932.YCL029C  with value: 0.1404
# 4 : 	 is node  4932.YPL269W  with value: 0.1404
# 5 : 	 is node  4932.YOL069W  with value: 0.1397
# 6 : 	 is node  4932.YOR195W  with value: 0.1396
# 7 : 	 is node  4932.YJL030W  with value: 0.1394
# 8 : 	 is node  4932.YPL018W  with value: 0.1393
# 9 : 	 is node  4932.YDL028C  with value: 0.1390
# 10 : 	 is node  4932.YBR107C  with value: 0.1387
#
#  Centrality Measure in Cluster: 17 Page Rank
# 1 : 	 is node  4932.YCL029C  with value: 0.0158
# 2 : 	 is node  4932.YEL061C  with value: 0.0155
# 3 : 	 is node  4932.YLR045C  with value: 0.0150
# 4 : 	 is node  4932.YPL269W  with value: 0.0148
# 5 : 	 is node  4932.YOR195W  with value: 0.0140
# 6 : 	 is node  4932.YDL028C  with value: 0.0134
# 7 : 	 is node  4932.YJL030W  with value: 0.0128
# 8 : 	 is node  4932.YFR028C  with value: 0.0125
# 9 : 	 is node  4932.YOL069W  with value: 0.0124
# 10 : 	 is node  4932.YBR107C  with value: 0.0123
#
#  Centrality Measure in Cluster: 18 Degree
# 1 : 	 is node  4932.YMR304C-A  with value: 16.0000
# 2 : 	 is node  4932.YCR013C  with value: 14.0000
# 3 : 	 is node  4932.YHR056W-A  with value: 13.0000
# 4 : 	 is node  4932.YBL071C  with value: 13.0000
# 5 : 	 is node  4932.YPR136C  with value: 11.0000
# 6 : 	 is node  4932.YMR151W  with value: 11.0000
# 7 : 	 is node  4932.YLR163W-A  with value: 11.0000
# 8 : 	 is node  4932.YKL165C-A  with value: 11.0000
# 9 : 	 is node  4932.YAL016C-B  with value: 11.0000
# 10 : 	 is node  4932.YPR044C  with value: 10.0000
#
#  Centrality Measure in Cluster: 18 Eigenvector
# 1 : 	 is node  4932.YCR013C  with value: 0.3029
# 2 : 	 is node  4932.YHR056W-A  with value: 0.3000
# 3 : 	 is node  4932.YBL071C  with value: 0.3000
# 4 : 	 is node  4932.YPR136C  with value: 0.2854
# 5 : 	 is node  4932.YMR151W  with value: 0.2854
# 6 : 	 is node  4932.YLR163W-A  with value: 0.2854
# 7 : 	 is node  4932.YKL165C-A  with value: 0.2854
# 8 : 	 is node  4932.YAL016C-B  with value: 0.2854
# 9 : 	 is node  4932.YMR304C-A  with value: 0.2718
# 10 : 	 is node  4932.YNL319W  with value: 0.2623
#
#  Centrality Measure in Cluster: 18 Page Rank
# 1 : 	 is node  4932.YGR182C  with value: 0.0194
# 2 : 	 is node  4932.YGL102C  with value: 0.0193
# 3 : 	 is node  4932.YOR012W  with value: 0.0192
# 4 : 	 is node  4932.YLL044W  with value: 0.0186
# 5 : 	 is node  4932.YPR044C  with value: 0.0186
# 6 : 	 is node  4932.YMR304C-A  with value: 0.0176
# 7 : 	 is node  4932.YLR062C  with value: 0.0175
# 8 : 	 is node  4932.YLR125W  with value: 0.0170
# 9 : 	 is node  4932.YCR013C  with value: 0.0162
# 10 : 	 is node  4932.YBR113W  with value: 0.0158
#
#  Centrality Measure in Cluster: 19 Degree
# 1 : 	 is node  4932.YOR272W  with value: 220.0000
# 2 : 	 is node  4932.YCL054W  with value: 216.0000
# 3 : 	 is node  4932.YGR103W  with value: 215.0000
# 4 : 	 is node  4932.YMR049C  with value: 213.0000
# 5 : 	 is node  4932.YDR496C  with value: 210.0000
# 6 : 	 is node  4932.YOR206W  with value: 209.0000
# 7 : 	 is node  4932.YNL110C  with value: 209.0000
# 8 : 	 is node  4932.YKR081C  with value: 209.0000
# 9 : 	 is node  4932.YHR052W  with value: 207.0000
# 10 : 	 is node  4932.YNL075W  with value: 205.0000
#
#  Centrality Measure in Cluster: 19 Eigenvector
# 1 : 	 is node  4932.YOR272W  with value: 0.0922
# 2 : 	 is node  4932.YGR103W  with value: 0.0911
# 3 : 	 is node  4932.YCL054W  with value: 0.0908
# 4 : 	 is node  4932.YOR206W  with value: 0.0901
# 5 : 	 is node  4932.YNL110C  with value: 0.0899
# 6 : 	 is node  4932.YMR049C  with value: 0.0899
# 7 : 	 is node  4932.YKR081C  with value: 0.0899
# 8 : 	 is node  4932.YHR052W  with value: 0.0898
# 9 : 	 is node  4932.YDR496C  with value: 0.0897
# 10 : 	 is node  4932.YNL075W  with value: 0.0884
#
#  Centrality Measure in Cluster: 19 Page Rank
# 1 : 	 is node  4932.YOR272W  with value: 0.0065
# 2 : 	 is node  4932.YGR103W  with value: 0.0064
# 3 : 	 is node  4932.YCL054W  with value: 0.0064
# 4 : 	 is node  4932.YMR049C  with value: 0.0063
# 5 : 	 is node  4932.YPL043W  with value: 0.0062
# 6 : 	 is node  4932.YDR496C  with value: 0.0062
# 7 : 	 is node  4932.YKR081C  with value: 0.0062
# 8 : 	 is node  4932.YOL077C  with value: 0.0061
# 9 : 	 is node  4932.YNL110C  with value: 0.0061
# 10 : 	 is node  4932.YOR206W  with value: 0.0061
#
#  Centrality Measure in Cluster: 20 Degree
# 1 : 	 is node  4932.YPL013C  with value: 88.0000
# 2 : 	 is node  4932.YKL003C  with value: 87.0000
# 3 : 	 is node  4932.YBR146W  with value: 87.0000
# 4 : 	 is node  4932.YGR220C  with value: 85.0000
# 5 : 	 is node  4932.YBR251W  with value: 85.0000
# 6 : 	 is node  4932.YNL005C  with value: 84.0000
# 7 : 	 is node  4932.YJL063C  with value: 84.0000
# 8 : 	 is node  4932.YPL183W-A  with value: 83.0000
# 9 : 	 is node  4932.YJR113C  with value: 83.0000
# 10 : 	 is node  4932.YHL004W  with value: 83.0000
#
#  Centrality Measure in Cluster: 20 Eigenvector
# 1 : 	 is node  4932.YPL013C  with value: 0.1227
# 2 : 	 is node  4932.YKL003C  with value: 0.1226
# 3 : 	 is node  4932.YBR146W  with value: 0.1226
# 4 : 	 is node  4932.YBR251W  with value: 0.1220
# 5 : 	 is node  4932.YHL004W  with value: 0.1209
# 6 : 	 is node  4932.YDR337W  with value: 0.1208
# 7 : 	 is node  4932.YDR041W  with value: 0.1208
# 8 : 	 is node  4932.YJR113C  with value: 0.1206
# 9 : 	 is node  4932.YGR220C  with value: 0.1204
# 10 : 	 is node  4932.YNL005C  with value: 0.1203
#
#  Centrality Measure in Cluster: 20 Page Rank
# 1 : 	 is node  4932.YGR220C  with value: 0.0150
# 2 : 	 is node  4932.YPL013C  with value: 0.0148
# 3 : 	 is node  4932.YBR146W  with value: 0.0144
# 4 : 	 is node  4932.YKL003C  with value: 0.0142
# 5 : 	 is node  4932.YJL063C  with value: 0.0140
# 6 : 	 is node  4932.YNL005C  with value: 0.0139
# 7 : 	 is node  4932.YJR113C  with value: 0.0139
# 8 : 	 is node  4932.YBR251W  with value: 0.0137
# 9 : 	 is node  4932.YCR003W  with value: 0.0137
# 10 : 	 is node  4932.YDR237W  with value: 0.0136
#
#  Centrality Measure in Cluster: 21 Degree
# 1 : 	 is node  4932.YNL031C  with value: 91.0000
# 2 : 	 is node  4932.YPR023C  with value: 77.0000
# 3 : 	 is node  4932.YOL012C  with value: 76.0000
# 4 : 	 is node  4932.YGR252W  with value: 75.0000
# 5 : 	 is node  4932.YBR010W  with value: 68.0000
# 6 : 	 is node  4932.YDR224C  with value: 64.0000
# 7 : 	 is node  4932.YNL330C  with value: 62.0000
# 8 : 	 is node  4932.YDR225W  with value: 61.0000
# 9 : 	 is node  4932.YJL168C  with value: 59.0000
# 10 : 	 is node  4932.YER164W  with value: 58.0000
#
#  Centrality Measure in Cluster: 21 Eigenvector
# 1 : 	 is node  4932.YPR023C  with value: 0.2012
# 2 : 	 is node  4932.YNL031C  with value: 0.1815
# 3 : 	 is node  4932.YNL330C  with value: 0.1757
# 4 : 	 is node  4932.YGR252W  with value: 0.1586
# 5 : 	 is node  4932.YOL012C  with value: 0.1553
# 6 : 	 is node  4932.YNL021W  with value: 0.1486
# 7 : 	 is node  4932.YOL004W  with value: 0.1484
# 8 : 	 is node  4932.YOL068C  with value: 0.1425
# 9 : 	 is node  4932.YBR010W  with value: 0.1418
# 10 : 	 is node  4932.YDR225W  with value: 0.1411
#
#  Centrality Measure in Cluster: 21 Page Rank
# 1 : 	 is node  4932.YNL031C  with value: 0.0167
# 2 : 	 is node  4932.YGR252W  with value: 0.0133
# 3 : 	 is node  4932.YOL012C  with value: 0.0131
# 4 : 	 is node  4932.YPR023C  with value: 0.0124
# 5 : 	 is node  4932.YBR010W  with value: 0.0122
# 6 : 	 is node  4932.YJL168C  with value: 0.0117
# 7 : 	 is node  4932.YDR224C  with value: 0.0114
# 8 : 	 is node  4932.YDR225W  with value: 0.0110
# 9 : 	 is node  4932.YHR119W  with value: 0.0107
# 10 : 	 is node  4932.YER164W  with value: 0.0106
#
#  Centrality Measure in Cluster: 22 Degree
# 1 : 	 is node  4932.YDL047W  with value: 38.0000
# 2 : 	 is node  4932.YDL134C  with value: 34.0000
# 3 : 	 is node  4932.YAL016W  with value: 34.0000
# 4 : 	 is node  4932.YLR433C  with value: 33.0000
# 5 : 	 is node  4932.YKL190W  with value: 33.0000
# 6 : 	 is node  4932.YML057W  with value: 32.0000
# 7 : 	 is node  4932.YGL190C  with value: 29.0000
# 8 : 	 is node  4932.YML016C  with value: 28.0000
# 9 : 	 is node  4932.YPL152W  with value: 27.0000
# 10 : 	 is node  4932.YDR075W  with value: 26.0000
#
#  Centrality Measure in Cluster: 22 Eigenvector
# 1 : 	 is node  4932.YAL016W  with value: 0.2321
# 2 : 	 is node  4932.YDL134C  with value: 0.2312
# 3 : 	 is node  4932.YDL047W  with value: 0.2253
# 4 : 	 is node  4932.YPL152W  with value: 0.2217
# 5 : 	 is node  4932.YGL190C  with value: 0.2206
# 6 : 	 is node  4932.YLR433C  with value: 0.2202
# 7 : 	 is node  4932.YML057W  with value: 0.2196
# 8 : 	 is node  4932.YDR075W  with value: 0.2165
# 9 : 	 is node  4932.YKL190W  with value: 0.2155
# 10 : 	 is node  4932.YNL201C  with value: 0.2024
#
#  Centrality Measure in Cluster: 22 Page Rank
# 1 : 	 is node  4932.YDL047W  with value: 0.0160
# 2 : 	 is node  4932.YLR433C  with value: 0.0140
# 3 : 	 is node  4932.YAL016W  with value: 0.0139
# 4 : 	 is node  4932.YML057W  with value: 0.0139
# 5 : 	 is node  4932.YKL190W  with value: 0.0138
# 6 : 	 is node  4932.YDL134C  with value: 0.0133
# 7 : 	 is node  4932.YML016C  with value: 0.0125
# 8 : 	 is node  4932.YDR040C  with value: 0.0121
# 9 : 	 is node  4932.YGL190C  with value: 0.0119
# 10 : 	 is node  4932.YPL152W  with value: 0.0104
#
#  Centrality Measure in Cluster: 23 Degree
# 1 : 	 is node  4932.YLR025W  with value: 26.0000
# 2 : 	 is node  4932.YMR077C  with value: 25.0000
# 3 : 	 is node  4932.YCL008C  with value: 25.0000
# 4 : 	 is node  4932.YPL084W  with value: 24.0000
# 5 : 	 is node  4932.YOR275C  with value: 23.0000
# 6 : 	 is node  4932.YKL041W  with value: 23.0000
# 7 : 	 is node  4932.YKL002W  with value: 22.0000
# 8 : 	 is node  4932.YPR173C  with value: 21.0000
# 9 : 	 is node  4932.YPL065W  with value: 21.0000
# 10 : 	 is node  4932.YNR006W  with value: 21.0000
#
#  Centrality Measure in Cluster: 23 Eigenvector
# 1 : 	 is node  4932.YLR025W  with value: 0.2527
# 2 : 	 is node  4932.YMR077C  with value: 0.2498
# 3 : 	 is node  4932.YCL008C  with value: 0.2404
# 4 : 	 is node  4932.YKL041W  with value: 0.2396
# 5 : 	 is node  4932.YKL002W  with value: 0.2342
# 6 : 	 is node  4932.YPL084W  with value: 0.2330
# 7 : 	 is node  4932.YLR417W  with value: 0.2265
# 8 : 	 is node  4932.YJR102C  with value: 0.2265
# 9 : 	 is node  4932.YPL065W  with value: 0.2235
# 10 : 	 is node  4932.YNR006W  with value: 0.2228
#
#  Centrality Measure in Cluster: 23 Page Rank
# 1 : 	 is node  4932.YLR025W  with value: 0.0243
# 2 : 	 is node  4932.YCL008C  with value: 0.0236
# 3 : 	 is node  4932.YOR275C  with value: 0.0228
# 4 : 	 is node  4932.YOR322C  with value: 0.0227
# 5 : 	 is node  4932.YMR077C  with value: 0.0227
# 6 : 	 is node  4932.YPL084W  with value: 0.0217
# 7 : 	 is node  4932.YOR253W  with value: 0.0212
# 8 : 	 is node  4932.YKL041W  with value: 0.0209
# 9 : 	 is node  4932.YKL002W  with value: 0.0199
# 10 : 	 is node  4932.YPR173C  with value: 0.0199
#
#  Centrality Measure in Cluster: 24 Degree
# 1 : 	 is node  4932.YOL047C  with value: 8.0000
# 2 : 	 is node  4932.YHR184W  with value: 8.0000
# 3 : 	 is node  4932.YOR177C  with value: 7.0000
# 4 : 	 is node  4932.YOL163W  with value: 7.0000
# 5 : 	 is node  4932.YOL091W  with value: 7.0000
# 6 : 	 is node  4932.YAL018C  with value: 7.0000
# 7 : 	 is node  4932.YOL162W  with value: 6.0000
# 8 : 	 is node  4932.YOL015W  with value: 6.0000
# 9 : 	 is node  4932.YLR341W  with value: 6.0000
# 10 : 	 is node  4932.YLL057C  with value: 6.0000
#
#  Centrality Measure in Cluster: 24 Eigenvector
# 1 : 	 is node  4932.YHR184W  with value: 0.3867
# 2 : 	 is node  4932.YOL091W  with value: 0.3824
# 3 : 	 is node  4932.YOR177C  with value: 0.3824
# 4 : 	 is node  4932.YDR273W  with value: 0.3631
# 5 : 	 is node  4932.YDL239C  with value: 0.3488
# 6 : 	 is node  4932.YGL170C  with value: 0.2702
# 7 : 	 is node  4932.YOL015W  with value: 0.2461
# 8 : 	 is node  4932.YHR185C  with value: 0.1863
# 9 : 	 is node  4932.YLR227C  with value: 0.1863
# 10 : 	 is node  4932.YOR042W  with value: 0.1767
#
#  Centrality Measure in Cluster: 24 Page Rank
# 1 : 	 is node  4932.YOL163W  with value: 0.0277
# 2 : 	 is node  4932.YLL057C  with value: 0.0248
# 3 : 	 is node  4932.YHR184W  with value: 0.0242
# 4 : 	 is node  4932.YOL162W  with value: 0.0237
# 5 : 	 is node  4932.YOL047C  with value: 0.0232
# 6 : 	 is node  4932.YOL015W  with value: 0.0220
# 7 : 	 is node  4932.YOL129W  with value: 0.0216
# 8 : 	 is node  4932.YAL018C  with value: 0.0212
# 9 : 	 is node  4932.YOL036W  with value: 0.0211
# 10 : 	 is node  4932.YOL091W  with value: 0.0204
#
#  Centrality Measure in Cluster: 25 Degree
# 1 : 	 is node  4932.YHL050C  with value: 37.0000
# 2 : 	 is node  4932.YHR218W  with value: 36.0000
# 3 : 	 is node  4932.YHL049C  with value: 35.0000
# 4 : 	 is node  4932.YBL111C  with value: 35.0000
# 5 : 	 is node  4932.YFL066C  with value: 34.0000
# 6 : 	 is node  4932.YLL067C  with value: 30.0000
# 7 : 	 is node  4932.YHR218W-A  with value: 30.0000
# 8 : 	 is node  4932.YLR462W  with value: 29.0000
# 9 : 	 is node  4932.YHR219W  with value: 29.0000
# 10 : 	 is node  4932.YLR466W  with value: 28.0000
#
#  Centrality Measure in Cluster: 25 Eigenvector
# 1 : 	 is node  4932.YHR218W  with value: 0.2357
# 2 : 	 is node  4932.YBL111C  with value: 0.2313
# 3 : 	 is node  4932.YHR218W-A  with value: 0.2157
# 4 : 	 is node  4932.YFL066C  with value: 0.2098
# 5 : 	 is node  4932.YHL050C  with value: 0.2058
# 6 : 	 is node  4932.YLL067C  with value: 0.1995
# 7 : 	 is node  4932.YJL225C  with value: 0.1944
# 8 : 	 is node  4932.YHL049C  with value: 0.1932
# 9 : 	 is node  4932.YLR462W  with value: 0.1930
# 10 : 	 is node  4932.YHR219W  with value: 0.1915
#
#  Centrality Measure in Cluster: 25 Page Rank
# 1 : 	 is node  4932.YHL050C  with value: 0.0130
# 2 : 	 is node  4932.YHL049C  with value: 0.0111
# 3 : 	 is node  4932.YHR218W  with value: 0.0110
# 4 : 	 is node  4932.YFL066C  with value: 0.0109
# 5 : 	 is node  4932.YBL111C  with value: 0.0104
# 6 : 	 is node  4932.YLL067C  with value: 0.0099
# 7 : 	 is node  4932.YHR219W  with value: 0.0095
# 8 : 	 is node  4932.YFL067W  with value: 0.0093
# 9 : 	 is node  4932.YHR218W-A  with value: 0.0089
# 10 : 	 is node  4932.YNL339C  with value: 0.0087
#
#  Centrality Measure in Cluster: 26 Degree
# 1 : 	 is node  4932.YJR129C  with value: 15.0000
# 2 : 	 is node  4932.YBR271W  with value: 15.0000
# 3 : 	 is node  4932.YIL064W  with value: 14.0000
# 4 : 	 is node  4932.YNL092W  with value: 13.0000
# 5 : 	 is node  4932.YIL110W  with value: 13.0000
# 6 : 	 is node  4932.YDR198C  with value: 13.0000
# 7 : 	 is node  4932.YBR261C  with value: 13.0000
# 8 : 	 is node  4932.YPL208W  with value: 12.0000
# 9 : 	 is node  4932.YBR141C  with value: 12.0000
# 10 : 	 is node  4932.YNL063W  with value: 11.0000
#
#  Centrality Measure in Cluster: 26 Eigenvector
# 1 : 	 is node  4932.YBR271W  with value: 0.3124
# 2 : 	 is node  4932.YJR129C  with value: 0.3083
# 3 : 	 is node  4932.YIL064W  with value: 0.2904
# 4 : 	 is node  4932.YDR198C  with value: 0.2844
# 5 : 	 is node  4932.YBR261C  with value: 0.2836
# 6 : 	 is node  4932.YNL092W  with value: 0.2722
# 7 : 	 is node  4932.YPL208W  with value: 0.2719
# 8 : 	 is node  4932.YNL063W  with value: 0.2577
# 9 : 	 is node  4932.YBR141C  with value: 0.2565
# 10 : 	 is node  4932.YIL110W  with value: 0.2564
#
#  Centrality Measure in Cluster: 26 Page Rank
# 1 : 	 is node  4932.YJR129C  with value: 0.0506
# 2 : 	 is node  4932.YBR271W  with value: 0.0501
# 3 : 	 is node  4932.YIL064W  with value: 0.0477
# 4 : 	 is node  4932.YNL092W  with value: 0.0467
# 5 : 	 is node  4932.YIL110W  with value: 0.0457
# 6 : 	 is node  4932.YBR141C  with value: 0.0447
# 7 : 	 is node  4932.YDR198C  with value: 0.0445
# 8 : 	 is node  4932.YBR261C  with value: 0.0438
# 9 : 	 is node  4932.YMR209C  with value: 0.0423
# 10 : 	 is node  4932.YER101C  with value: 0.0412
#
#  Centrality Measure in Cluster: 27 Degree
# 1 : 	 is node  4932.YGR281W  with value: 18.0000
# 2 : 	 is node  4932.YOR153W  with value: 17.0000
# 3 : 	 is node  4932.YBL005W  with value: 15.0000
# 4 : 	 is node  4932.YGL013C  with value: 13.0000
# 5 : 	 is node  4932.YOR162C  with value: 12.0000
# 6 : 	 is node  4932.YDR406W  with value: 12.0000
# 7 : 	 is node  4932.YDR011W  with value: 12.0000
# 8 : 	 is node  4932.YCL069W  with value: 12.0000
# 9 : 	 is node  4932.YOR378W  with value: 11.0000
# 10 : 	 is node  4932.YGR224W  with value: 10.0000
#
#  Centrality Measure in Cluster: 27 Eigenvector
# 1 : 	 is node  4932.YGR281W  with value: 0.3484
# 2 : 	 is node  4932.YOR153W  with value: 0.3228
# 3 : 	 is node  4932.YBL005W  with value: 0.3085
# 4 : 	 is node  4932.YDR011W  with value: 0.2841
# 5 : 	 is node  4932.YGL013C  with value: 0.2694
# 6 : 	 is node  4932.YDR406W  with value: 0.2687
# 7 : 	 is node  4932.YOL156W  with value: 0.2526
# 8 : 	 is node  4932.YJL219W  with value: 0.2526
# 9 : 	 is node  4932.YDR072C  with value: 0.2511
# 10 : 	 is node  4932.YNL318C  with value: 0.2273
#
#  Centrality Measure in Cluster: 27 Page Rank
# 1 : 	 is node  4932.YGR281W  with value: 0.0195
# 2 : 	 is node  4932.YOR153W  with value: 0.0191
# 3 : 	 is node  4932.YBL005W  with value: 0.0167
# 4 : 	 is node  4932.YCL069W  with value: 0.0167
# 5 : 	 is node  4932.YOR378W  with value: 0.0157
# 6 : 	 is node  4932.YOR162C  with value: 0.0156
# 7 : 	 is node  4932.YCR075C  with value: 0.0149
# 8 : 	 is node  4932.YGL013C  with value: 0.0147
# 9 : 	 is node  4932.YBL094C  with value: 0.0142
# 10 : 	 is node  4932.YER119C  with value: 0.0134
#
#  Centrality Measure in Cluster: 28 Degree
# 1 : 	 is node  4932.YBR255W  with value: 6.0000
# 2 : 	 is node  4932.YBR197C  with value: 5.0000
# 3 : 	 is node  4932.YPR153W  with value: 4.0000
# 4 : 	 is node  4932.YMR126C  with value: 4.0000
# 5 : 	 is node  4932.YKL098W  with value: 4.0000
# 6 : 	 is node  4932.YBR266C  with value: 2.0000
# 7 : 	 is node  4932.YBR259W  with value: 2.0000
# 8 : 	 is node  4932.YBR209W  with value: 1.0000
#
#  Centrality Measure in Cluster: 28 Eigenvector
# 1 : 	 is node  4932.YBR255W  with value: 0.4761
# 2 : 	 is node  4932.YBR197C  with value: 0.4387
# 3 : 	 is node  4932.YPR153W  with value: 0.4184
# 4 : 	 is node  4932.YKL098W  with value: 0.4184
# 5 : 	 is node  4932.YMR126C  with value: 0.4184
# 6 : 	 is node  4932.YBR259W  with value: 0.1494
# 7 : 	 is node  4932.YBR266C  with value: 0.1494
# 8 : 	 is node  4932.YBR209W  with value: 0.1048
#
#  Centrality Measure in Cluster: 28 Page Rank
# 1 : 	 is node  4932.YBR255W  with value: 0.2058
# 2 : 	 is node  4932.YBR197C  with value: 0.1676
# 3 : 	 is node  4932.YMR126C  with value: 0.1372
# 4 : 	 is node  4932.YKL098W  with value: 0.1358
# 5 : 	 is node  4932.YPR153W  with value: 0.1357
# 6 : 	 is node  4932.YBR266C  with value: 0.0860
# 7 : 	 is node  4932.YBR259W  with value: 0.0860
# 8 : 	 is node  4932.YBR209W  with value: 0.0458

# %%
# write data file
central_nodes = {'COMMUNITY':[], 'RANK':[], 'DEGREE_NODE':[],'DEGREE_VALUE':[], 'EIGENVECTOR_NODE':[],'EIGENVECTOR_VALUE':[], 'KATZ_NODE':[], 'KATZ_VALUE':[], 'PAGERANK_NODE':[], 'PAGERANK_VALUE':[], 'BETWEENESS_NODE':[], 'BETWEENESS_VALUE':[]}
 
for i in range(number_of_communities):
    G = G_cluster[i]
    #the number of nodes in top10 central nodes
    row_number = min(len(G.nodes),10)
    central_nodes['COMMUNITY'].extend([i]*row_number)
    central_nodes['RANK'].extend(list(range(1,row_number+1)))
    
    for j in range(row_number):
        central_nodes['DEGREE_NODE'].append(top10_final[i][0][j][1][5:])
        central_nodes['DEGREE_VALUE'].append(top10_final[i][0][j][0])
        central_nodes['EIGENVECTOR_NODE'].append(top10_final[i][1][j][1][5:])
        central_nodes['EIGENVECTOR_VALUE'].append(top10_final[i][1][j][0])
        central_nodes['PAGERANK_NODE'].append(top10_final[i][2][j][1][5:])
        central_nodes['PAGERANK_VALUE'].append(top10_final[i][2][j][0])

df = pd.DataFrame(central_nodes, columns= ['COMMUNITY','RANK', 'DEGREE_NODE','DEGREE_VALUE', 'EIGENVECTOR_NODE','EIGENVECTOR_VALUE', 'PAGERANK_NODE', 'PAGERANK_VALUE'])
df.to_csv("CDC28_Centrality_Louvain_thresh%s.csv" %threshold_score, index=False)
