# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import scipy as sp

# Data reading
import pandas as pd
import csv
import pickle

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# networkx

import networkx as nx
from networkx.algorithms import community
from networkx.algorithms.community import greedy_modularity_communities
from networkx.algorithms.community import k_clique_communities

from community import community_louvain

import scipy.sparse.linalg

# %%
# Read networks from file
#G_CDC28=nx.read_weighted_edgelist("./../Data/4932_protein_links_v11_0.txt",comments="#",nodetype=str)
G_CDC28=nx.read_weighted_edgelist("4932.protein.links.v11.0.txt",comments="#",nodetype=str)

print('number of nodes of G:',nx.number_of_nodes(G_CDC28))
print('number of edges of G:',nx.number_of_edges(G_CDC28))
# Out:
# number of nodes of G: 6574
# number of edges of G: 922983

# %%
node_target = '4932.YBR160W' #CDC28
print('The target node has %i links'%G_CDC28.degree(node_target))
# Out:
# The target node has 1401 links

# %%
# Choose the network to be analyzed below
G0=G_CDC28
# delete those edges with a combined score of <= thershold_score (small confidence)
threshold_score = 700
#threshold_score = 0
for edge in G0.edges: 
    G0.get_edge_data(edge[0],edge[1])
    weight = list(G0.get_edge_data(edge[0],edge[1]).values())
    #print('qwe',weight[0])
    if(weight[0] <= threshold_score):
        G0.remove_edge(edge[0],edge[1])
# restrict to largest connected component
largest_cc = max(nx.connected_components(G0),key=len)
G0=G0.subgraph(largest_cc).copy()

# %% [markdown]
# ## Prune Top 30 degree nodes

# %%
dgList=list(G0.degree())
dgList= sorted(dgList,key = lambda x: x[1])
dgList.reverse()
prune_list = [x[0] for x in dgList[:30]]
G0.remove_nodes_from(prune_list)

# %%
partLouvain = community_louvain.best_partition(G0,resolution=0.5,random_state=1)
number_of_communities = max(list(partLouvain.values()))+1
print('# of partitions for Louvain modularity =',number_of_communities)
# Out:
# # of partitions for Louvain modularity = 30

# %%
node_target = '4932.YBR160W' # CDC28
print('The target protein CDC28 belongs to community #',partLouvain[node_target])
# Out:
# The target protein CDC28 belongs to community # 4

# %%
# define the communities as separate graphs

#subgraph dict with community number as key and subgraph as value
G_cluster = {}

#node dict with community number as key and node as value
nodes = {}
for i in range(number_of_communities):
    nodes[i] = []

for name, community in partLouvain.items():
    nodes[community].append(name)
    
for key in nodes.keys():
    G_cluster[key] = G0.subgraph(nodes[key])

# %%
top10_final = {}
for i in range(number_of_communities):
    top10_final[i] = []
    G = G_cluster[i]
    measuresNames=["Degree","Eigenvector","Page Rank"]
    if len(G.nodes)>2:
        listMeasures = [dict(nx.degree(G)),nx.eigenvector_centrality_numpy(G),nx.pagerank(G)]
   
    if len(G.nodes)<=2:
        listMeasures = [dict(nx.degree(G)),nx.eigenvector_centrality(G),nx.pagerank(G)]
   
    for idx,dictMeasure in enumerate(listMeasures):
        top10 = [[dictMeasure[k],k] for k in dictMeasure.keys()] # Choose the 10 largest values
        top10.sort(reverse=True)
        top10_final[i].append(top10)
        print("\n Centrality Measure in Cluster:",str(i),measuresNames[idx])
        for idx,pair in enumerate(top10[:10]):
            print(str(idx+1),": \t is node ",pair[1],' with value: %.4f \t' %(pair[0]))
# Out:
# : 0.2251
# 4 : 	 is node  4932.YPL106C  with value: 0.2160
# 5 : 	 is node  4932.YNL064C  with value: 0.2109
# 6 : 	 is node  4932.YJL034W  with value: 0.2104
# 7 : 	 is node  4932.YNL007C  with value: 0.2066
# 8 : 	 is node  4932.YDR258C  with value: 0.1873
# 9 : 	 is node  4932.YBR101C  with value: 0.1766
# 10 : 	 is node  4932.YFL016C  with value: 0.1689
#
#  Centrality Measure in Cluster: 16 Page Rank
# 1 : 	 is node  4932.YJL034W  with value: 0.0166
# 2 : 	 is node  4932.YPL240C  with value: 0.0165
# 3 : 	 is node  4932.YMR186W  with value: 0.0132
# 4 : 	 is node  4932.YOR027W  with value: 0.0126
# 5 : 	 is node  4932.YPL106C  with value: 0.0111
# 6 : 	 is node  4932.YNL064C  with value: 0.0106
# 7 : 	 is node  4932.YCL043C  with value: 0.0105
# 8 : 	 is node  4932.YNL007C  with value: 0.0104
# 9 : 	 is node  4932.YKL073W  with value: 0.0097
# 10 : 	 is node  4932.YEL029C  with value: 0.0090
#
#  Centrality Measure in Cluster: 17 Degree
# 1 : 	 is node  4932.YEL061C  with value: 69.0000
# 2 : 	 is node  4932.YCL029C  with value: 68.0000
# 3 : 	 is node  4932.YPL269W  with value: 67.0000
# 4 : 	 is node  4932.YLR045C  with value: 65.0000
# 5 : 	 is node  4932.YOR195W  with value: 63.0000
# 6 : 	 is node  4932.YDL028C  with value: 62.0000
# 7 : 	 is node  4932.YOL069W  with value: 60.0000
# 8 : 	 is node  4932.YJL030W  with value: 60.0000
# 9 : 	 is node  4932.YPL018W  with value: 57.0000
# 10 : 	 is node  4932.YMR117C  with value: 57.0000
#
#  Centrality Measure in Cluster: 17 Eigenvector
# 1 : 	 is node  4932.YEL061C  with value: 0.1420
# 2 : 	 is node  4932.YLR045C  with value: 0.1406
# 3 : 	 is node  4932.YCL029C  with value: 0.1405
# 4 : 	 is node  4932.YPL269W  with value: 0.1404
# 5 : 	 is node  4932.YOL069W  with value: 0.1398
# 6 : 	 is node  4932.YOR195W  with value: 0.1396
# 7 : 	 is node  4932.YJL030W  with value: 0.1394
# 8 : 	 is node  4932.YPL018W  with value: 0.1393
# 9 : 	 is node  4932.YDL028C  with value: 0.1390
# 10 : 	 is node  4932.YBR107C  with value: 0.1387
#
#  Centrality Measure in Cluster: 17 Page Rank
# 1 : 	 is node  4932.YCL029C  with value: 0.0156
# 2 : 	 is node  4932.YEL061C  with value: 0.0152
# 3 : 	 is node  4932.YLR045C  with value: 0.0147
# 4 : 	 is node  4932.YPL269W  with value: 0.0145
# 5 : 	 is node  4932.YOR195W  with value: 0.0136
# 6 : 	 is node  4932.YDL028C  with value: 0.0131
# 7 : 	 is node  4932.YJL030W  with value: 0.0125
# 8 : 	 is node  4932.YOL069W  with value: 0.0121
# 9 : 	 is node  4932.YBR107C  with value: 0.0119
# 10 : 	 is node  4932.YPL209C  with value: 0.0112
#
#  Centrality Measure in Cluster: 18 Degree
# 1 : 	 is node  4932.YMR304C-A  with value: 16.0000
# 2 : 	 is node  4932.YCR013C  with value: 14.0000
# 3 : 	 is node  4932.YHR056W-A  with value: 13.0000
# 4 : 	 is node  4932.YBL071C  with value: 13.0000
# 5 : 	 is node  4932.YPR136C  with value: 11.0000
# 6 : 	 is node  4932.YMR151W  with value: 11.0000
# 7 : 	 is node  4932.YLR163W-A  with value: 11.0000
# 8 : 	 is node  4932.YKL165C-A  with value: 11.0000
# 9 : 	 is node  4932.YAL016C-B  with value: 11.0000
# 10 : 	 is node  4932.YPR044C  with value: 10.0000
#
#  Centrality Measure in Cluster: 18 Eigenvector
# 1 : 	 is node  4932.YCR013C  with value: 0.3029
# 2 : 	 is node  4932.YHR056W-A  with value: 0.3000
# 3 : 	 is node  4932.YBL071C  with value: 0.3000
# 4 : 	 is node  4932.YAL016C-B  with value: 0.2854
# 5 : 	 is node  4932.YMR151W  with value: 0.2854
# 6 : 	 is node  4932.YPR136C  with value: 0.2854
# 7 : 	 is node  4932.YLR163W-A  with value: 0.2854
# 8 : 	 is node  4932.YKL165C-A  with value: 0.2854
# 9 : 	 is node  4932.YMR304C-A  with value: 0.2720
# 10 : 	 is node  4932.YNL319W  with value: 0.2622
#
#  Centrality Measure in Cluster: 18 Page Rank
# 1 : 	 is node  4932.YGL102C  with value: 0.0210
# 2 : 	 is node  4932.YGR182C  with value: 0.0207
# 3 : 	 is node  4932.YLL044W  with value: 0.0202
# 4 : 	 is node  4932.YPR044C  with value: 0.0202
# 5 : 	 is node  4932.YMR304C-A  with value: 0.0195
# 6 : 	 is node  4932.YLR062C  with value: 0.0190
# 7 : 	 is node  4932.YMR031W-A  with value: 0.0188
# 8 : 	 is node  4932.YLR125W  with value: 0.0185
# 9 : 	 is node  4932.YCR013C  with value: 0.0177
# 10 : 	 is node  4932.YBR113W  with value: 0.0171
#
#  Centrality Measure in Cluster: 19 Degree
# 1 : 	 is node  4932.YOR272W  with value: 214.0000
# 2 : 	 is node  4932.YCL054W  with value: 210.0000
# 3 : 	 is node  4932.YGR103W  with value: 209.0000
# 4 : 	 is node  4932.YMR049C  with value: 208.0000
# 5 : 	 is node  4932.YDR496C  with value: 205.0000
# 6 : 	 is node  4932.YOR206W  with value: 204.0000
# 7 : 	 is node  4932.YKR081C  with value: 203.0000
# 8 : 	 is node  4932.YNL110C  with value: 202.0000
# 9 : 	 is node  4932.YHR052W  with value: 201.0000
# 10 : 	 is node  4932.YNL061W  with value: 200.0000
#
#  Centrality Measure in Cluster: 19 Eigenvector
# 1 : 	 is node  4932.YOR272W  with value: 0.0946
# 2 : 	 is node  4932.YGR103W  with value: 0.0933
# 3 : 	 is node  4932.YCL054W  with value: 0.0931
# 4 : 	 is node  4932.YOR206W  with value: 0.0925
# 5 : 	 is node  4932.YMR049C  with value: 0.0923
# 6 : 	 is node  4932.YKR081C  with value: 0.0920
# 7 : 	 is node  4932.YDR496C  with value: 0.0920
# 8 : 	 is node  4932.YNL110C  with value: 0.0919
# 9 : 	 is node  4932.YHR052W  with value: 0.0919
# 10 : 	 is node  4932.YNL075W  with value: 0.0905
#
#  Centrality Measure in Cluster: 19 Page Rank
# 1 : 	 is node  4932.YOR272W  with value: 0.0068
# 2 : 	 is node  4932.YGR103W  with value: 0.0067
# 3 : 	 is node  4932.YCL054W  with value: 0.0067
# 4 : 	 is node  4932.YMR049C  with value: 0.0067
# 5 : 	 is node  4932.YPL043W  with value: 0.0065
# 6 : 	 is node  4932.YDR496C  with value: 0.0065
# 7 : 	 is node  4932.YKR081C  with value: 0.0065
# 8 : 	 is node  4932.YOL077C  with value: 0.0064
# 9 : 	 is node  4932.YOR206W  with value: 0.0064
# 10 : 	 is node  4932.YNL061W  with value: 0.0064
#
#  Centrality Measure in Cluster: 20 Degree
# 1 : 	 is node  4932.YNL031C  with value: 92.0000
# 2 : 	 is node  4932.YGR252W  with value: 78.0000
# 3 : 	 is node  4932.YPR023C  with value: 76.0000
# 4 : 	 is node  4932.YOL012C  with value: 76.0000
# 5 : 	 is node  4932.YBR010W  with value: 69.0000
# 6 : 	 is node  4932.YNL330C  with value: 65.0000
# 7 : 	 is node  4932.YDR224C  with value: 63.0000
# 8 : 	 is node  4932.YDR225W  with value: 62.0000
# 9 : 	 is node  4932.YBR009C  with value: 61.0000
# 10 : 	 is node  4932.YJL168C  with value: 58.0000
#
#  Centrality Measure in Cluster: 20 Eigenvector
# 1 : 	 is node  4932.YPR023C  with value: 0.1995
# 2 : 	 is node  4932.YNL031C  with value: 0.1807
# 3 : 	 is node  4932.YNL330C  with value: 0.1771
# 4 : 	 is node  4932.YGR252W  with value: 0.1592
# 5 : 	 is node  4932.YOL012C  with value: 0.1541
# 6 : 	 is node  4932.YNL021W  with value: 0.1497
# 7 : 	 is node  4932.YOL004W  with value: 0.1481
# 8 : 	 is node  4932.YOL068C  with value: 0.1430
# 9 : 	 is node  4932.YBR010W  with value: 0.1416
# 10 : 	 is node  4932.YDR225W  with value: 0.1406
#
#  Centrality Measure in Cluster: 20 Page Rank
# 1 : 	 is node  4932.YNL031C  with value: 0.0156
# 2 : 	 is node  4932.YGR252W  with value: 0.0129
# 3 : 	 is node  4932.YOL012C  with value: 0.0121
# 4 : 	 is node  4932.YBR010W  with value: 0.0114
# 5 : 	 is node  4932.YPR023C  with value: 0.0114
# 6 : 	 is node  4932.YJL168C  with value: 0.0105
# 7 : 	 is node  4932.YDR225W  with value: 0.0104
# 8 : 	 is node  4932.YDR224C  with value: 0.0103
# 9 : 	 is node  4932.YBR009C  with value: 0.0103
# 10 : 	 is node  4932.YNL330C  with value: 0.0102
#
#  Centrality Measure in Cluster: 21 Degree
# 1 : 	 is node  4932.YGR200C  with value: 17.0000
# 2 : 	 is node  4932.YJR129C  with value: 15.0000
# 3 : 	 is node  4932.YBR271W  with value: 15.0000
# 4 : 	 is node  4932.YBL071W-A  with value: 15.0000
# 5 : 	 is node  4932.YIL064W  with value: 14.0000
# 6 : 	 is node  4932.YNL092W  with value: 13.0000
# 7 : 	 is node  4932.YML014W  with value: 13.0000
# 8 : 	 is node  4932.YIL110W  with value: 13.0000
# 9 : 	 is node  4932.YDR198C  with value: 13.0000
# 10 : 	 is node  4932.YBR261C  with value: 13.0000
#
#  Centrality Measure in Cluster: 21 Eigenvector
# 1 : 	 is node  4932.YBR271W  with value: 0.2991
# 2 : 	 is node  4932.YJR129C  with value: 0.2963
# 3 : 	 is node  4932.YIL064W  with value: 0.2781
# 4 : 	 is node  4932.YDR198C  with value: 0.2737
# 5 : 	 is node  4932.YBR261C  with value: 0.2729
# 6 : 	 is node  4932.YNL092W  with value: 0.2622
# 7 : 	 is node  4932.YPL208W  with value: 0.2607
# 8 : 	 is node  4932.YBR141C  with value: 0.2541
# 9 : 	 is node  4932.YNL063W  with value: 0.2513
# 10 : 	 is node  4932.YIL110W  with value: 0.2454
#
#  Centrality Measure in Cluster: 21 Page Rank
# 1 : 	 is node  4932.YGR200C  with value: 0.0280
# 2 : 	 is node  4932.YBL071W-A  with value: 0.0254
# 3 : 	 is node  4932.YER138W-A  with value: 0.0242
# 4 : 	 is node  4932.YBR271W  with value: 0.0235
# 5 : 	 is node  4932.YJR129C  with value: 0.0234
# 6 : 	 is node  4932.YIL064W  with value: 0.0224
# 7 : 	 is node  4932.YBR141C  with value: 0.0218
# 8 : 	 is node  4932.YNL092W  with value: 0.0216
# 9 : 	 is node  4932.YIL110W  with value: 0.0215
# 10 : 	 is node  4932.YDR261W-B  with value: 0.0211
#
#  Centrality Measure in Cluster: 22 Degree
# 1 : 	 is node  4932.YLR025W  with value: 26.0000
# 2 : 	 is node  4932.YMR077C  with value: 25.0000
# 3 : 	 is node  4932.YCL008C  with value: 25.0000
# 4 : 	 is node  4932.YPL084W  with value: 24.0000
# 5 : 	 is node  4932.YOR275C  with value: 23.0000
# 6 : 	 is node  4932.YKL041W  with value: 23.0000
# 7 : 	 is node  4932.YNR006W  with value: 22.0000
# 8 : 	 is node  4932.YKL002W  with value: 22.0000
# 9 : 	 is node  4932.YPR173C  with value: 21.0000
# 10 : 	 is node  4932.YPL065W  with value: 21.0000
#
#  Centrality Measure in Cluster: 22 Eigenvector
# 1 : 	 is node  4932.YLR025W  with value: 0.2527
# 2 : 	 is node  4932.YMR077C  with value: 0.2498
# 3 : 	 is node  4932.YCL008C  with value: 0.2404
# 4 : 	 is node  4932.YKL041W  with value: 0.2396
# 5 : 	 is node  4932.YKL002W  with value: 0.2342
# 6 : 	 is node  4932.YPL084W  with value: 0.2330
# 7 : 	 is node  4932.YLR417W  with value: 0.2265
# 8 : 	 is node  4932.YJR102C  with value: 0.2265
# 9 : 	 is node  4932.YPL065W  with value: 0.2235
# 10 : 	 is node  4932.YNR006W  with value: 0.2234
#
#  Centrality Measure in Cluster: 22 Page Rank
# 1 : 	 is node  4932.YLR025W  with value: 0.0294
# 2 : 	 is node  4932.YOR322C  with value: 0.0286
# 3 : 	 is node  4932.YCL008C  with value: 0.0281
# 4 : 	 is node  4932.YOR275C  with value: 0.0275
# 5 : 	 is node  4932.YMR077C  with value: 0.0274
# 6 : 	 is node  4932.YPL084W  with value: 0.0263
# 7 : 	 is node  4932.YNR006W  with value: 0.0256
# 8 : 	 is node  4932.YKR035W-A  with value: 0.0255
# 9 : 	 is node  4932.YKL041W  with value: 0.0253
# 10 : 	 is node  4932.YKL002W  with value: 0.0241
#
#  Centrality Measure in Cluster: 23 Degree
# 1 : 	 is node  4932.YHR184W  with value: 8.0000
# 2 : 	 is node  4932.YOR177C  with value: 7.0000
# 3 : 	 is node  4932.YOL091W  with value: 7.0000
# 4 : 	 is node  4932.YOL015W  with value: 6.0000
# 5 : 	 is node  4932.YLR341W  with value: 6.0000
# 6 : 	 is node  4932.YFR012W-A  with value: 6.0000
# 7 : 	 is node  4932.YDR273W  with value: 6.0000
# 8 : 	 is node  4932.YDL239C  with value: 6.0000
# 9 : 	 is node  4932.YHR103W  with value: 5.0000
# 10 : 	 is node  4932.YGR147C  with value: 5.0000
#
#  Centrality Measure in Cluster: 23 Eigenvector
# 1 : 	 is node  4932.YHR184W  with value: 0.3868
# 2 : 	 is node  4932.YOR177C  with value: 0.3826
# 3 : 	 is node  4932.YOL091W  with value: 0.3826
# 4 : 	 is node  4932.YDR273W  with value: 0.3633
# 5 : 	 is node  4932.YDL239C  with value: 0.3490
# 6 : 	 is node  4932.YGL170C  with value: 0.2703
# 7 : 	 is node  4932.YOL015W  with value: 0.2462
# 8 : 	 is node  4932.YLR227C  with value: 0.1865
# 9 : 	 is node  4932.YHR185C  with value: 0.1865
# 10 : 	 is node  4932.YOR042W  with value: 0.1768
#
#  Centrality Measure in Cluster: 23 Page Rank
# 1 : 	 is node  4932.YHR184W  with value: 0.0584
# 2 : 	 is node  4932.YOL015W  with value: 0.0524
# 3 : 	 is node  4932.YOL091W  with value: 0.0487
# 4 : 	 is node  4932.YFR012W-A  with value: 0.0485
# 5 : 	 is node  4932.YER034W  with value: 0.0485
# 6 : 	 is node  4932.YOR177C  with value: 0.0471
# 7 : 	 is node  4932.YLR341W  with value: 0.0449
# 8 : 	 is node  4932.YDL239C  with value: 0.0436
# 9 : 	 is node  4932.YDR273W  with value: 0.0432
# 10 : 	 is node  4932.YIL108W  with value: 0.0417
#
#  Centrality Measure in Cluster: 24 Degree
# 1 : 	 is node  4932.YMR058W  with value: 27.0000
# 2 : 	 is node  4932.YGL071W  with value: 27.0000
# 3 : 	 is node  4932.YER145C  with value: 25.0000
# 4 : 	 is node  4932.YGL255W  with value: 17.0000
# 5 : 	 is node  4932.YMR319C  with value: 15.0000
# 6 : 	 is node  4932.YDR270W  with value: 15.0000
# 7 : 	 is node  4932.YLR411W  with value: 14.0000
# 8 : 	 is node  4932.YLR220W  with value: 14.0000
# 9 : 	 is node  4932.YJL056C  with value: 14.0000
# 10 : 	 is node  4932.YHL040C  with value: 14.0000
#
#  Centrality Measure in Cluster: 24 Eigenvector
# 1 : 	 is node  4932.YMR058W  with value: 0.3515
# 2 : 	 is node  4932.YGL071W  with value: 0.3264
# 3 : 	 is node  4932.YER145C  with value: 0.3049
# 4 : 	 is node  4932.YDR270W  with value: 0.2224
# 5 : 	 is node  4932.YHL040C  with value: 0.2213
# 6 : 	 is node  4932.YMR319C  with value: 0.2179
# 7 : 	 is node  4932.YLR136C  with value: 0.1999
# 8 : 	 is node  4932.YLR214W  with value: 0.1952
# 9 : 	 is node  4932.YLR220W  with value: 0.1813
# 10 : 	 is node  4932.YEL065W  with value: 0.1670
#
#  Centrality Measure in Cluster: 24 Page Rank
# 1 : 	 is node  4932.YGL071W  with value: 0.0275
# 2 : 	 is node  4932.YMR058W  with value: 0.0266
# 3 : 	 is node  4932.YER145C  with value: 0.0266
# 4 : 	 is node  4932.YGL255W  with value: 0.0199
# 5 : 	 is node  4932.YJL056C  with value: 0.0177
# 6 : 	 is node  4932.YOL163W  with value: 0.0156
# 7 : 	 is node  4932.YLR411W  with value: 0.0154
# 8 : 	 is node  4932.YDR270W  with value: 0.0151
# 9 : 	 is node  4932.YMR319C  with value: 0.0150
# 10 : 	 is node  4932.YLR220W  with value: 0.0143
#
#  Centrality Measure in Cluster: 25 Degree
# 1 : 	 is node  4932.YHL050C  with value: 37.0000
# 2 : 	 is node  4932.YHR218W  with value: 36.0000
# 3 : 	 is node  4932.YHL049C  with value: 35.0000
# 4 : 	 is node  4932.YBL111C  with value: 35.0000
# 5 : 	 is node  4932.YFL066C  with value: 34.0000
# 6 : 	 is node  4932.YLL067C  with value: 30.0000
# 7 : 	 is node  4932.YHR218W-A  with value: 30.0000
# 8 : 	 is node  4932.YLR462W  with value: 29.0000
# 9 : 	 is node  4932.YHR219W  with value: 29.0000
# 10 : 	 is node  4932.YLR466W  with value: 28.0000
#
#  Centrality Measure in Cluster: 25 Eigenvector
# 1 : 	 is node  4932.YHR218W  with value: 0.2357
# 2 : 	 is node  4932.YBL111C  with value: 0.2313
# 3 : 	 is node  4932.YHR218W-A  with value: 0.2157
# 4 : 	 is node  4932.YFL066C  with value: 0.2098
# 5 : 	 is node  4932.YHL050C  with value: 0.2058
# 6 : 	 is node  4932.YLL067C  with value: 0.1995
# 7 : 	 is node  4932.YJL225C  with value: 0.1944
# 8 : 	 is node  4932.YHL049C  with value: 0.1932
# 9 : 	 is node  4932.YLR462W  with value: 0.1930
# 10 : 	 is node  4932.YHR219W  with value: 0.1915
#
#  Centrality Measure in Cluster: 25 Page Rank
# 1 : 	 is node  4932.YHL050C  with value: 0.0134
# 2 : 	 is node  4932.YHL049C  with value: 0.0116
# 3 : 	 is node  4932.YHR218W  with value: 0.0114
# 4 : 	 is node  4932.YFL066C  with value: 0.0112
# 5 : 	 is node  4932.YBL111C  with value: 0.0108
# 6 : 	 is node  4932.YLL067C  with value: 0.0103
# 7 : 	 is node  4932.YHR219W  with value: 0.0098
# 8 : 	 is node  4932.YFL067W  with value: 0.0095
# 9 : 	 is node  4932.YHR218W-A  with value: 0.0092
# 10 : 	 is node  4932.YNL339C  with value: 0.0091
#
#  Centrality Measure in Cluster: 26 Degree
# 1 : 	 is node  4932.YOR153W  with value: 18.0000
# 2 : 	 is node  4932.YGR281W  with value: 18.0000
# 3 : 	 is node  4932.YBL005W  with value: 15.0000
# 4 : 	 is node  4932.YGL013C  with value: 13.0000
# 5 : 	 is node  4932.YOR378W  with value: 12.0000
# 6 : 	 is node  4932.YOR162C  with value: 12.0000
# 7 : 	 is node  4932.YDR406W  with value: 12.0000
# 8 : 	 is node  4932.YDR011W  with value: 12.0000
# 9 : 	 is node  4932.YCL069W  with value: 11.0000
# 10 : 	 is node  4932.YGR224W  with value: 10.0000
#
#  Centrality Measure in Cluster: 26 Eigenvector
# 1 : 	 is node  4932.YGR281W  with value: 0.3477
# 2 : 	 is node  4932.YOR153W  with value: 0.3254
# 3 : 	 is node  4932.YBL005W  with value: 0.3078
# 4 : 	 is node  4932.YDR011W  with value: 0.2835
# 5 : 	 is node  4932.YGL013C  with value: 0.2688
# 6 : 	 is node  4932.YDR406W  with value: 0.2682
# 7 : 	 is node  4932.YJL219W  with value: 0.2521
# 8 : 	 is node  4932.YOL156W  with value: 0.2521
# 9 : 	 is node  4932.YDR072C  with value: 0.2506
# 10 : 	 is node  4932.YNL318C  with value: 0.2269
#
#  Centrality Measure in Cluster: 26 Page Rank
# 1 : 	 is node  4932.YOR153W  with value: 0.0240
# 2 : 	 is node  4932.YGR281W  with value: 0.0222
# 3 : 	 is node  4932.YBL005W  with value: 0.0190
# 4 : 	 is node  4932.YOR378W  with value: 0.0188
# 5 : 	 is node  4932.YOR162C  with value: 0.0176
# 6 : 	 is node  4932.YGL013C  with value: 0.0167
# 7 : 	 is node  4932.YCL069W  with value: 0.0166
# 8 : 	 is node  4932.YBL094C  with value: 0.0156
# 9 : 	 is node  4932.YDR011W  with value: 0.0147
# 10 : 	 is node  4932.YDR406W  with value: 0.0145
#
#  Centrality Measure in Cluster: 27 Degree
# 1 : 	 is node  4932.YBR255W  with value: 6.0000
# 2 : 	 is node  4932.YBR197C  with value: 5.0000
# 3 : 	 is node  4932.YPR153W  with value: 4.0000
# 4 : 	 is node  4932.YMR126C  with value: 4.0000
# 5 : 	 is node  4932.YKL098W  with value: 4.0000
# 6 : 	 is node  4932.YBR266C  with value: 2.0000
# 7 : 	 is node  4932.YBR259W  with value: 2.0000
# 8 : 	 is node  4932.YBR209W  with value: 1.0000
#
#  Centrality Measure in Cluster: 27 Eigenvector
# 1 : 	 is node  4932.YBR255W  with value: 0.4761
# 2 : 	 is node  4932.YBR197C  with value: 0.4387
# 3 : 	 is node  4932.YPR153W  with value: 0.4184
# 4 : 	 is node  4932.YKL098W  with value: 0.4184
# 5 : 	 is node  4932.YMR126C  with value: 0.4184
# 6 : 	 is node  4932.YBR259W  with value: 0.1494
# 7 : 	 is node  4932.YBR266C  with value: 0.1494
# 8 : 	 is node  4932.YBR209W  with value: 0.1048
#
#  Centrality Measure in Cluster: 27 Page Rank
# 1 : 	 is node  4932.YBR255W  with value: 0.2058
# 2 : 	 is node  4932.YBR197C  with value: 0.1676
# 3 : 	 is node  4932.YMR126C  with value: 0.1372
# 4 : 	 is node  4932.YKL098W  with value: 0.1358
# 5 : 	 is node  4932.YPR153W  with value: 0.1357
# 6 : 	 is node  4932.YBR259W  with value: 0.0860
# 7 : 	 is node  4932.YBR266C  with value: 0.0860
# 8 : 	 is node  4932.YBR209W  with value: 0.0458
#
#  Centrality Measure in Cluster: 28 Degree
# 1 : 	 is node  4932.YLR154W-F  with value: 4.0000
# 2 : 	 is node  4932.YLR154W-E  with value: 4.0000
# 3 : 	 is node  4932.YLR154W-B  with value: 4.0000
# 4 : 	 is node  4932.YLR154C-H  with value: 4.0000
# 5 : 	 is node  4932.YLR154C-G  with value: 4.0000
#
#  Centrality Measure in Cluster: 28 Eigenvector
# 1 : 	 is node  4932.YLR154C-G  with value: 0.4472
# 2 : 	 is node  4932.YLR154W-F  with value: 0.4472
# 3 : 	 is node  4932.YLR154C-H  with value: 0.4472
# 4 : 	 is node  4932.YLR154W-E  with value: 0.4472
# 5 : 	 is node  4932.YLR154W-B  with value: 0.4472
#
#  Centrality Measure in Cluster: 28 Page Rank
# 1 : 	 is node  4932.YLR154W-F  with value: 0.2000
# 2 : 	 is node  4932.YLR154W-B  with value: 0.2000
# 3 : 	 is node  4932.YLR154C-H  with value: 0.2000
# 4 : 	 is node  4932.YLR154W-E  with value: 0.2000
# 5 : 	 is node  4932.YLR154C-G  with value: 0.2000
#
#  Centrality Measure in Cluster: 29 Degree
# 1 : 	 is node  4932.YGL123C-A  with value: 0.0000
#
#  Centrality Measure in Cluster: 29 Eigenvector
# 1 : 	 is node  4932.YGL123C-A  with value: 1.0000
#
#  Centrality Measure in Cluster: 29 Page Rank
# 1 : 	 is node  4932.YGL123C-A  with value: 1.0000

# %%
# write data file
central_nodes = {'COMMUNITY':[], 'RANK':[], 'DEGREE_NODE':[],'DEGREE_VALUE':[], 'EIGENVECTOR_NODE':[],'EIGENVECTOR_VALUE':[], 'KATZ_NODE':[], 'KATZ_VALUE':[], 'PAGERANK_NODE':[], 'PAGERANK_VALUE':[], 'BETWEENESS_NODE':[], 'BETWEENESS_VALUE':[]}
 
for i in range(number_of_communities):
    G = G_cluster[i]
    #the number of nodes in top10 central nodes
    row_number = min(len(G.nodes),10)
    central_nodes['COMMUNITY'].extend([i]*row_number)
    central_nodes['RANK'].extend(list(range(1,row_number+1)))
    
    for j in range(row_number):
        central_nodes['DEGREE_NODE'].append(top10_final[i][0][j][1][5:])
        central_nodes['DEGREE_VALUE'].append(top10_final[i][0][j][0])
        central_nodes['EIGENVECTOR_NODE'].append(top10_final[i][1][j][1][5:])
        central_nodes['EIGENVECTOR_VALUE'].append(top10_final[i][1][j][0])
        central_nodes['PAGERANK_NODE'].append(top10_final[i][2][j][1][5:])
        central_nodes['PAGERANK_VALUE'].append(top10_final[i][2][j][0])

df = pd.DataFrame(central_nodes, columns= ['COMMUNITY','RANK', 'DEGREE_NODE','DEGREE_VALUE', 'EIGENVECTOR_NODE','EIGENVECTOR_VALUE', 'PAGERANK_NODE', 'PAGERANK_VALUE'])
df.to_csv("CDC28_Centrality_Louvain_thresh_pruned%s.csv" %threshold_score, index=False)
